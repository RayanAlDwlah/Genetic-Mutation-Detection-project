# %% [markdown]
# # 01 Data Download

# %% [markdown]
# ## Source Priority
# 1. ClinVar (labels)
# 2. gnomAD (frequency features)
# 3. dbNSFP (precomputed functional features)
# 4. UniProt (protein sequences for ESM-2)

# %% [markdown]
# ## Target Raw Paths
# - `data/raw/clinvar/variant_summary.txt`
# - `data/raw/gnomad/gnomad.exomes.vcf.gz`
# - `data/raw/dbnsfp/dbNSFP4.tsv.gz`
# - `data/raw/uniprot/human_proteome.fasta`

# %%
# TODO: add authenticated download commands and checksums for each source.
